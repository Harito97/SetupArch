# %% [markdown]
# # Can't input with the Bamboo method - the Vietnamese input - in the visual-studio-code-bin package

# %% [markdown]
# # Can't find the value of PrtSc code to assign it for a short cut function
#
# - thằng lenovo nó gán function native cho tất cả các phím hàng trên cùng (thuong dung Fn + phim F1, F2, ... -> dung duoc F1, F2, ...)
#
# - bởi vậy nó không nhận phím tắt do mk set đè lên
