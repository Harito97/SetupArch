# %% [markdown]
# # Step 1. Install Arch from a boot
#
# More information in [here:archinstall](install_guide/archinstall.ipynb)

# %% [markdown]
# # Step 2. Install a DE (if need)
#
# More information in [here:hyprdots](https://github.com/prasanthrangan/hyprdots)
#
# ```bash
# # Install
# pacman -Sy git
# git clone --depth 1 https://github.com/prasanthrangan/hyprdots ~/Clone/
# cd ~/Clone/Scripts
# ./install.sh
#
# # Update
# cd ~/Clone/Scripts
# git pull
# ./install.sh -r
# ```
#
# Naturally, it should set up firefox, yay (if you choose it),

# %% [markdown]
# # Step 3. Basic for my work
#
# More information in [here:setup for work]()
