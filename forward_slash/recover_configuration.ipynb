# %% [markdown]
# # Move to the main working directory

# %%
import os

WORKING_DIR = '/Data/Projects/SetupArch/forward_slash/'
os.chdir(WORKING_DIR)
print(os.getcwd())
# Out:
# /Data/Projects/SetupArch/forward_slash

# %% [markdown]
# # Update package in
