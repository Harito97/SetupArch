# %% [markdown]
# # Intro
#
# The python version: 3.11
#
# Use case: Develop AI product

# %% [markdown]
# # 02:20pm 16/07/2024
#
# Basic python venv:
# ```bash
# ❯ source /Data/Projects/venv_manager/ai_work#311/bin/activate
# ❯ pip list
# Package    Version
# ---------- -------
# pip        24.0
# setuptools 65.5.0
#
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# ```

# %% [markdown]
# # 02:24pm 16/07/2024
#
# To use python kernel with jupyter notebook on vscode $\to$ install:
# ```bash
# Package           Version
# ----------------- -----------
# asttokens         2.4.1
# comm              0.2.2
# debugpy           1.8.2
# decorator         5.1.1
# executing         2.0.1
# ipykernel         6.29.5
# ipython           8.26.0
# jedi              0.19.1
# jupyter_client    8.6.2
# jupyter_core      5.7.2
# matplotlib-inline 0.1.7
# nest-asyncio      1.6.0
# packaging         24.1
# parso             0.8.4
# pexpect           4.9.0
# # pip               24.0
# platformdirs      4.2.2
# prompt_toolkit    3.0.47
# psutil            6.0.0
# ptyprocess        0.7.0
# pure-eval         0.2.2
# Pygments          2.18.0
# python-dateutil   2.9.0.post0
# pyzmq             26.0.3
# # setuptools        65.5.0
# six               1.16.0
# stack-data        0.6.3
# tornado           6.4.1
# traitlets         5.14.3
# typing_extensions 4.12.2
# wcwidth           0.2.13
# ```

# %% [markdown]
# # 11:47am 17/07/2024
#
# To have ability to control mouse, keyboard, ... with command
# ```bash
# pip install pyautogui keyboard
# Successfully installed keyboard-0.13.5 mouseinfo-0.1.3 pyautogui-0.9.54 pygetwindow-0.0.9 pymsgbox-1.0.9 pyperclip-1.9.0 pyrect-0.2.0 pyscreeze-0.1.30 python3-Xlib-0.15 pytweening-1.2.0
# ```
